# %% [markdown]
# # 만개의 레시피 검색어 "비건" 검색결과 레시피 크롤링

# %%
# 필요한 패키지 불러오기
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
import csv
import time
import pandas as pd

# %%
import pandas as pd
import numpy as np

from selenium import webdriver
from selenium.webdriver import ActionChains as AC
from tqdm.notebook import tqdm
import re # 정규표현식 - 해시태그 제거
import time

# %%
##1페이지에 있는 url 크롤링

# 크롬창 띄우기
driver = webdriver.Chrome("./chromedriver.exe")
driver.get("https://www.10000recipe.com/recipe/list.html?q=%EB%B9%84%EA%B1%B4")
time.sleep(3)

dict = {}   # 전체 데이터를 담을 딕셔너리 생성


 # 비건 검색해 나온 레시피 창 url크롤링
url_list = []
title_list = []

count=0

while(count<1):
    count=count+1
    # URL_raw 크롤링 시작
    articles = "a.common_sp_link" # 중간에 띄어쓰기는 .으로 대체, selector는 >로 이동
    article_raw = driver.find_elements_by_css_selector(articles)
    #article_raw[0]

    # 크롤링한 url 정제 시작
    for article in article_raw:
        url = article.get_attribute('href')   
        url_list.append(url)
        print(url)

print("")
print('url갯수: ', len(url_list))
#print('title갯수: ', len(title_list))

df1 = pd.DataFrame({'url':url_list})
# Out:
# https://shop.10000recipe.com/goods/goods_view.php?goodsNo=1000007266&utm_source=10k_recipe&utm_medium=recipe_search_list&utm_campaign=g%EB%B0%80%EC%8A%A4%EC%9B%90%EB%A7%B5%EC%BD%A9%EB%8B%AC%EC%BD%A9%EC%BD%A9%EA%B3%A0%EA%B8%B0%EC%8A%A4%ED%85%8C%EC%9D%B4%ED%81%AC2%EC%A2%8510%ED%8C%A9
# https://www.10000recipe.com/recipe/6930572
# https://www.10000recipe.com/recipe/6932067
# https://www.10000recipe.com/recipe/6929074
# https://www.10000recipe.com/recipe/6943455
# https://www.10000recipe.com/recipe/6928801
# https://www.10000recipe.com/recipe/6938309
# https://www.10000recipe.com/recipe/6919198
# https://www.10000recipe.com/recipe/6915631
# https://www.10000recipe.com/recipe/6959067
# https://www.10000recipe.com/recipe/6957529
# https://www.10000recipe.com/recipe/6874477
# https://www.10000recipe.com/recipe/6920142
# https://www.10000recipe.com/recipe/6930220
# https://www.10000recipe.com/recipe/6888169
# https://www.10000recipe.com/recipe/6919961
# ...

# %%
##2페이지에 있는 url 크롤링

# 크롬창 띄우기
driver = webdriver.Chrome("./chromedriver.exe")
driver.get("https://www.10000recipe.com/recipe/list.html?q=%EB%B9%84%EA%B1%B4&order=reco&page=2")
time.sleep(3)

dict = {}   # 전체 데이터를 담을 딕셔너리 생성


 # 비건 검색해 나온 레시피 창 url크롤링
url_list = []
title_list = []

count=0

while(count<1):
    count=count+1
    # URL_raw 크롤링 시작
    articles = "a.common_sp_link" # 중간에 띄어쓰기는 .으로 대체, selector는 >로 이동
    article_raw = driver.find_elements_by_css_selector(articles)
    #article_raw[0]

    # 크롤링한 url 정제 시작
    for article in article_raw:
        url = article.get_attribute('href')   
        url_list.append(url)
        print(url)

    # 1초 쉬어 주고,
    time.sleep(1)

print("")
print('url갯수: ', len(url_list))
#print('title갯수: ', len(title_list))

df2 = pd.DataFrame({'url':url_list})
# Out:
# https://shop.10000recipe.com/goods/goods_view.php?goodsNo=1000007266&utm_source=10k_recipe&utm_medium=recipe_search_list&utm_campaign=g%EB%B0%80%EC%8A%A4%EC%9B%90%EB%A7%B5%EC%BD%A9%EB%8B%AC%EC%BD%A9%EC%BD%A9%EA%B3%A0%EA%B8%B0%EC%8A%A4%ED%85%8C%EC%9D%B4%ED%81%AC2%EC%A2%8510%ED%8C%A9
# https://www.10000recipe.com/recipe/6955614
# https://www.10000recipe.com/recipe/6953229
# https://www.10000recipe.com/recipe/6953106
# https://www.10000recipe.com/recipe/6953101
# https://www.10000recipe.com/recipe/6951814
# https://www.10000recipe.com/recipe/6951511
# https://www.10000recipe.com/recipe/6951497
# https://www.10000recipe.com/recipe/6949524
# https://www.10000recipe.com/recipe/6949344
# https://www.10000recipe.com/recipe/6949314
# https://www.10000recipe.com/recipe/6949308
# https://www.10000recipe.com/recipe/6949272
# https://www.10000recipe.com/recipe/6948437
# https://www.10000recipe.com/recipe/6946765
# https://www.10000recipe.com/recipe/6946268
# ...

# %%
##3페이지에 있는 url 크롤링

# 크롬창 띄우기
driver = webdriver.Chrome("./chromedriver.exe")
driver.get("https://www.10000recipe.com/recipe/list.html?q=%EB%B9%84%EA%B1%B4&order=reco&page=3")
time.sleep(3)

dict = {}   # 전체 데이터를 담을 딕셔너리 생성


 # 비건 검색해 나온 레시피 창 url크롤링
url_list = []
title_list = []

count=0

while(count<1):
    count=count+1
    # URL_raw 크롤링 시작
    articles = "a.common_sp_link" # 중간에 띄어쓰기는 .으로 대체, selector는 >로 이동
    article_raw = driver.find_elements_by_css_selector(articles)
    #article_raw[0]

    # 크롤링한 url 정제 시작
    for article in article_raw:
        url = article.get_attribute('href')   
        url_list.append(url)
        print(url)

    # 1초 쉬어 주고,
    time.sleep(1)
print("")
print('url갯수: ', len(url_list))
#print('title갯수: ', len(title_list))

df3 = pd.DataFrame({'url':url_list})
# Out:
# https://shop.10000recipe.com/goods/goods_view.php?goodsNo=1000007266&utm_source=10k_recipe&utm_medium=recipe_search_list&utm_campaign=g%EB%B0%80%EC%8A%A4%EC%9B%90%EB%A7%B5%EC%BD%A9%EB%8B%AC%EC%BD%A9%EC%BD%A9%EA%B3%A0%EA%B8%B0%EC%8A%A4%ED%85%8C%EC%9D%B4%ED%81%AC2%EC%A2%8510%ED%8C%A9
# https://www.10000recipe.com/recipe/6909847
# https://www.10000recipe.com/recipe/6909611
# https://www.10000recipe.com/recipe/6907317
# https://www.10000recipe.com/recipe/6906538
# https://www.10000recipe.com/recipe/6905447
# https://www.10000recipe.com/recipe/6901356
# https://www.10000recipe.com/recipe/6893250
# https://www.10000recipe.com/recipe/6887735
# https://www.10000recipe.com/recipe/6886682
# https://www.10000recipe.com/recipe/6886242
# https://www.10000recipe.com/recipe/6883189
# https://www.10000recipe.com/recipe/6881383
# https://www.10000recipe.com/recipe/6881379
# https://www.10000recipe.com/recipe/6881377
# https://www.10000recipe.com/recipe/6881374
# ...

# %%
##4페이지에 있는 url 크롤링
# 크롬창 띄우기
driver = webdriver.Chrome("./chromedriver.exe")
driver.get("https://www.10000recipe.com/recipe/list.html?q=%EB%B9%84%EA%B1%B4&order=reco&page=4")
time.sleep(3)

dict = {}   # 전체 데이터를 담을 딕셔너리 생성


 # 비건 검색해 나온 레시피 창 url크롤링
url_list = []
title_list = []

count=0

while(count<1):
    count=count+1
    # URL_raw 크롤링 시작
    articles = "a.common_sp_link" # 중간에 띄어쓰기는 .으로 대체, selector는 >로 이동
    article_raw = driver.find_elements_by_css_selector(articles)
    #article_raw[0]

    # 크롤링한 url 정제 시작
    for article in article_raw:
        url = article.get_attribute('href')   
        url_list.append(url)
        print(url)

    # 1초 쉬어 주고,
    time.sleep(1)
print("")
print('url갯수: ', len(url_list))
#print('title갯수: ', len(title_list))

df4 = pd.DataFrame({'url':url_list})
# Out:
# https://shop.10000recipe.com/goods/goods_view.php?goodsNo=1000007266&utm_source=10k_recipe&utm_medium=recipe_search_list&utm_campaign=g%EB%B0%80%EC%8A%A4%EC%9B%90%EB%A7%B5%EC%BD%A9%EB%8B%AC%EC%BD%A9%EC%BD%A9%EA%B3%A0%EA%B8%B0%EC%8A%A4%ED%85%8C%EC%9D%B4%ED%81%AC2%EC%A2%8510%ED%8C%A9
# https://www.10000recipe.com/recipe/6867819
# https://www.10000recipe.com/recipe/6866546
# https://www.10000recipe.com/recipe/6866544
# https://www.10000recipe.com/recipe/6866536
# https://www.10000recipe.com/recipe/6866535
# https://www.10000recipe.com/recipe/6866533
# https://www.10000recipe.com/recipe/6866185
# https://www.10000recipe.com/recipe/6866090
# https://www.10000recipe.com/recipe/6865880
# https://www.10000recipe.com/recipe/6865878
# https://www.10000recipe.com/recipe/6865768
# https://www.10000recipe.com/recipe/6865763
# https://www.10000recipe.com/recipe/6865760
# https://www.10000recipe.com/recipe/6865752
# https://www.10000recipe.com/recipe/6865744
# ...

# %%
##5페이지에 있는 url 크롤링

# 크롬창 띄우기
driver = webdriver.Chrome("./chromedriver.exe")
driver.get("https://www.10000recipe.com/recipe/list.html?q=%EB%B9%84%EA%B1%B4&order=reco&page=5")
time.sleep(3)

dict = {}   # 전체 데이터를 담을 딕셔너리 생성


 # 비건 검색해 나온 레시피 창 url크롤링
url_list = []
title_list = []

count=0

while(count<1):
    count=count+1
    # URL_raw 크롤링 시작
    articles = "a.common_sp_link" # 중간에 띄어쓰기는 .으로 대체, selector는 >로 이동
    article_raw = driver.find_elements_by_css_selector(articles)
    #article_raw[0]

    # 크롤링한 url 정제 시작
    for article in article_raw:
        url = article.get_attribute('href')   
        url_list.append(url)
        print(url)

    # 1초 쉬어 주고,
    time.sleep(1)
print("")
print('url갯수: ', len(url_list))
#print('title갯수: ', len(title_list))

df5 = pd.DataFrame({'url':url_list})
# Out:
# https://shop.10000recipe.com/goods/goods_view.php?goodsNo=1000007266&utm_source=10k_recipe&utm_medium=recipe_search_list&utm_campaign=g%EB%B0%80%EC%8A%A4%EC%9B%90%EB%A7%B5%EC%BD%A9%EB%8B%AC%EC%BD%A9%EC%BD%A9%EA%B3%A0%EA%B8%B0%EC%8A%A4%ED%85%8C%EC%9D%B4%ED%81%AC2%EC%A2%8510%ED%8C%A9
# https://www.10000recipe.com/recipe/5770303
# https://www.10000recipe.com/recipe/5767976
# https://www.10000recipe.com/recipe/5767868
# https://www.10000recipe.com/recipe/5767692
# https://www.10000recipe.com/recipe/5767610
# https://www.10000recipe.com/recipe/5760789
# https://www.10000recipe.com/recipe/5756199
# https://www.10000recipe.com/recipe/5756194
# https://www.10000recipe.com/recipe/5756103
# https://www.10000recipe.com/recipe/5756100
# https://www.10000recipe.com/recipe/5750775
# https://www.10000recipe.com/recipe/5750737
# https://www.10000recipe.com/recipe/5663069
# https://www.10000recipe.com/recipe/5663034
# https://www.10000recipe.com/recipe/5649770
# ...

# %%
#df = pd.DataFrame({'url':url_list})
#크롤링한 레시피 url병합
df = pd.concat([df1,df2, df3, df4, df5], ignore_index=True)

# %%
df #병합된 dataframe확인
# Out:
#                                                    url
# 0    https://shop.10000recipe.com/goods/goods_view....
# 1           https://www.10000recipe.com/recipe/6930572
# 2           https://www.10000recipe.com/recipe/6932067
# 3           https://www.10000recipe.com/recipe/6929074
# 4           https://www.10000recipe.com/recipe/6943455
# ..                                                 ...
# 179         https://www.10000recipe.com/recipe/5649770
# 180         https://www.10000recipe.com/recipe/5647308
# 181         https://www.10000recipe.com/recipe/5644125
# 182         https://www.10000recipe.com/recipe/5644093
# 183         https://www.10000recipe.com/recipe/4569261
#
# [184 rows x 1 columns]

# %%
df.to_csv("10000_recipe_url_비건.csv", encoding='utf-8') #csv파일로 따로 저장

# %%
###############################################

# %%
url_load=pd.read_csv("10000_recipe_url_비건.csv", encoding='utf-8') #url파일 불러오기


num_list = len(url_load)

print(num_list)
url_load

dict = {}    # 전체 크롤링 데이터를 담을 그릇

number = 183  # 수집할 글 갯수 정하기

path = "./chromedriver.exe"

# 수집한 url 돌면서 데이터 수집
for i in tqdm(range(0, number)):
    # 글 띄우기
    url = url_load['url'][i]
    driver = webdriver.Chrome(path)  # 윈도우는 "chromedriver.exe"
    driver.get(url)   # 글 띄우기
    
    # 크롤링
    
    try:
     

        target_info = {}  # 개별 레시피 내용을 담을 딕셔너리 생성

        # 제목 크롤링 시작
        overlays = "div.view2_summary.st3"                                 
        tit = driver.find_element_by_css_selector(overlays)          # title
        title = tit.text
    
        # 재료 크롤링 시작
        overlays = "div.ready_ingre3"                                 
        ingre = driver.find_element_by_css_selector(overlays)          # title
        ingredient = ingre.text
    
        # 사진(pic) 크롤링
        overlays1 = "div.centeredcrop>img"
        img = driver.find_element_by_css_selector(overlays1)# 사진 선택
        #print(img)
        pic = img.get_attribute('src')      # 사진 url 크롤링
        pic
        #print(pic)
        
        # 내용 크롤링
        overlays = "div.view_step"                                 
        contents = driver.find_elements_by_css_selector(overlays)    # contents
        #print(contents)

        content_list = []
        for content in contents:
            content_list.append(content.text)
 
        content_str = ' '.join(content_list)                         # content_str

        # 글 하나는 target_info라는 딕셔너리에 담기게 되고,
        target_info['title'] = title
        target_info['ingredient'] = ingredient
        target_info['pic']=pic
        target_info['content'] = content_str

        # 각각의 글은 dict라는 딕셔너리에 담기게 됩니다.
        dict[i] = target_info
        time.sleep(1)
        
        # 크롤링이 성공하면 글 제목을 출력하게 되고,
        print(i, title)

        # 글 하나 크롤링 후 크롬 창을 닫습니다.
        driver.close()
        
    except Exception as e:
        print(e,'This page is error :',i)
        driver.close()
        time.sleep(1)
        continue
        
    # 에러나면 현재 크롬창을 닫고 다음 글(i+1)로 이동합니다.
    
    # 중간,중간에 파일로 저장하기
    if i == 30 or 50 or 80:
        # 판다스로 만들기
        import pandas as pd
        result_df = pd.DataFrame.from_dict(dict, 'index')

        # 저장하기
        result_df.to_excel("10000_recipe_비건.xlsx", encoding='utf-8-sig')
        time.sleep(3)

print('수집한 글 갯수: ', len(dict))
#print(dict)

# 판다스로 만들기
import pandas as pd
result_df = pd.DataFrame.from_dict(dict, 'index')
result_df

#result_df.to_excel("blog_content.xlsx", encoding='utf-8-sig')
# Out:
# 184
# ...
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.view2_summary.st3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 0
# 1 비건베이킹인데 너무 맛있는 감자 크래커!
# 비건베이킹이에요 ~!
# 감자 좋아하시나요? 저 메쉬드 포테이토 환장하고 먹는 귀신인데
# 요 크래커 정말 좋아해요
# 입이 삼삼하니 심심할때 먹다보면 어느새 뚝딱 없어져요
# 5인분 60분 이내 아무나
# 2 비건 통밀쿠키 ! 초간단에 맛있고 난리부르스
# 심지어 만들기도 쉬우니 금방만드셔서
# 순식간에 먹어버리는 신기한 일이 벌어집니다 ㅋ_ㅋ
# 2인분 30분 이내 아무나
# 3 고소한 콩가루 스콘 ! 비건레시피, 노버터 스콘
# 콩가루 베이킹을 좋아하여 이것저것 만들어 보며 제일 맛있는 레시피로 소개드려요 ~!
# 비건레시피라서 건강하고, 맛있으니 최고!
# 4인분 60분 이내 아무나
# 4 노버터, 노에그, 노밀크 비건 초콜릿 스콘 만들기
# 비건레시피 초콜릿 스콘이에요 !
# 코코아가루의 깊은 초콜릿 향이 더해져 깊은맛이 나는 스콘이에요
# 4인분 60분 이내 초급
# 5 NO35 비건쿠키
# 저희집은 밀가루 먹으면 안되서 이런 종류의 비건 쿠키를 자주 굽는 답니다.
# 칼로리가 낮고 단백질이 풍부한 햄프씨드가 들어간 아주 바싹한 설탕없이 바나나를 넣은 쿠키입니다.
# 양심의 가책없이 먹을수 있는 착한쿠키, 한끼 식사로도 좋답니다.
# 4인분 60분 이내 중급
# 6 비건 아몬드쿠키★
# 비건 베이킹에 관심이 생겨서 만들어본 쿠키예요
# No버터! No노오일! No노우유! No노글루텐!
# 이 4가지 조건을 생각하고 만들어봤답니다~
# 붓고 섞고 굽기만 하면 되는 아주 간단한 베이킹이예요
# 따라해보시겠어요?
# 2인분 60분 이내 아무나
# ...

# %%
result_df.to_csv("10000_recipe_채식.csv", encoding='utf-8') #csv파일로 저장
