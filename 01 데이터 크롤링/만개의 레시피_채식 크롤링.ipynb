# %% [markdown]
# # 만개의 레시피 검색어 "채식" 검색결과 레시피 크롤링

# %%
#필요한 패키지 불러오기
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
import csv
import time
import pandas as pd

# %%
import pandas as pd
import numpy as np

from selenium import webdriver
from selenium.webdriver import ActionChains as AC
from tqdm.notebook import tqdm
import re # 정규표현식 - 해시태그 제거
import time

# %%
##1페이지에 있는 url 크롤링

# 크롬창 띄우기
driver = webdriver.Chrome("./chromedriver.exe")
driver.get("https://www.10000recipe.com/recipe/list.html?q=%EC%B1%84%EC%8B%9D")
time.sleep(3)

dict = {}   # 전체 데이터를 담을 딕셔너리 생성


 # 비건 검색해 나온 레시피 창 url크롤링
url_list = []
title_list = []

count=0

while(count<1):
    count=count+1
    # URL_raw 크롤링 시작
    articles = "a.common_sp_link" # 중간에 띄어쓰기는 .으로 대체, selector는 >로 이동
    article_raw = driver.find_elements_by_css_selector(articles)
    #article_raw[0]

    # 크롤링한 url 정제 시작
    for article in article_raw:
        url = article.get_attribute('href')   
        url_list.append(url)
        print(url)
 
print("")
print('url갯수: ', len(url_list))
#print('title갯수: ', len(title_list))

df1 = pd.DataFrame({'url':url_list})
# Out:
# https://shop.10000recipe.com/goods/goods_view.php?goodsNo=1000007266&utm_source=10k_recipe&utm_medium=recipe_search_list&utm_campaign=g%EB%B0%80%EC%8A%A4%EC%9B%90%EB%A7%B5%EC%BD%A9%EB%8B%AC%EC%BD%A9%EC%BD%A9%EA%B3%A0%EA%B8%B0%EC%8A%A4%ED%85%8C%EC%9D%B4%ED%81%AC2%EC%A2%8510%ED%8C%A9
# https://www.10000recipe.com/recipe/6918300
# https://www.10000recipe.com/recipe/6877875
# https://www.10000recipe.com/recipe/6959723
# https://www.10000recipe.com/recipe/6891713
# https://www.10000recipe.com/recipe/6867496
# https://www.10000recipe.com/recipe/6876072
# https://www.10000recipe.com/recipe/6864194
# https://www.10000recipe.com/recipe/6594403
# https://www.10000recipe.com/recipe/6957529
# https://www.10000recipe.com/recipe/6888169
# https://www.10000recipe.com/recipe/6957557
# https://www.10000recipe.com/recipe/6907522
# https://www.10000recipe.com/recipe/6876770
# https://www.10000recipe.com/recipe/6865651
# https://www.10000recipe.com/recipe/6867399
# https://www.10000recipe.com/recipe/6927156
# https://www.10000recipe.com/recipe/6873771
# https://www.10000recipe.com/recipe/6866189
# https://www.10000recipe.com/recipe/6885929
# https://www.10000recipe.com/recipe/6894932
# https://www.10000recipe.com/recipe/6876707
# https://www.10000recipe.com/recipe/5532417
# https://www.10000recipe.com/recipe/6959374
# https://www.10000recipe.com/recipe/6958641
# https://www.10000recipe.com/recipe/6955762
# https://www.10000recipe.com/recipe/6945925
# https://www.10000recipe.com/recipe/6942103
# https://www.10000recipe.com/recipe/6941556
# https://www.10000recipe.com/recipe/6941187
# https://www.10000recipe.com/recipe/6940458
# https://www.10000recipe.com/recipe/6940452
# https://www.10000recipe.com/recipe/6937110
# https://www.10000recipe.com/recipe/6934332
# https://www.10000recipe.com/recipe/6933929
# https://www.10000recipe.com/recipe/6931502
# https://www.10000recipe.com/recipe/6924623
# https://www.10000recipe.com/recipe/6917944
# https://www.10000recipe.com/recipe/6917901
# https://www.10000recipe.com/recipe/6916537
# https://www.10000recipe.com/recipe/6916395
#
# url갯수:  41

# %%
##2페이지에 있는 url 크롤링

# 크롬창 띄우기
driver = webdriver.Chrome("./chromedriver.exe")
driver.get("https://www.10000recipe.com/recipe/list.html?q=%EC%B1%84%EC%8B%9D&order=reco&page=2")
time.sleep(3)

dict = {}   # 전체 데이터를 담을 딕셔너리 생성


 # 비건 검색해 나온 레시피 창 url크롤링
url_list = []
title_list = []

count=0

while(count<1):
    count=count+1
    # URL_raw 크롤링 시작
    articles = "a.common_sp_link" # 중간에 띄어쓰기는 .으로 대체, selector는 >로 이동
    article_raw = driver.find_elements_by_css_selector(articles)
    #article_raw[0]

    # 크롤링한 url 정제 시작
    for article in article_raw:
        url = article.get_attribute('href')   
        url_list.append(url)
        print(url)

    # 1초 쉬어 주고,
    time.sleep(1)

print("")
print('url갯수: ', len(url_list))
#print('title갯수: ', len(title_list))

df2 = pd.DataFrame({'url':url_list})
# Out:
# https://shop.10000recipe.com/goods/goods_view.php?goodsNo=1000007266&utm_source=10k_recipe&utm_medium=recipe_search_list&utm_campaign=g%EB%B0%80%EC%8A%A4%EC%9B%90%EB%A7%B5%EC%BD%A9%EB%8B%AC%EC%BD%A9%EC%BD%A9%EA%B3%A0%EA%B8%B0%EC%8A%A4%ED%85%8C%EC%9D%B4%ED%81%AC2%EC%A2%8510%ED%8C%A9
# https://www.10000recipe.com/recipe/6915773
# https://www.10000recipe.com/recipe/6909847
# https://www.10000recipe.com/recipe/6907952
# https://www.10000recipe.com/recipe/6907649
# https://www.10000recipe.com/recipe/6907317
# https://www.10000recipe.com/recipe/6898217
# https://www.10000recipe.com/recipe/6896079
# https://www.10000recipe.com/recipe/6894588
# https://www.10000recipe.com/recipe/6894185
# https://www.10000recipe.com/recipe/6887735
# https://www.10000recipe.com/recipe/6887183
# https://www.10000recipe.com/recipe/6886682
# https://www.10000recipe.com/recipe/6886242
# https://www.10000recipe.com/recipe/6885932
# https://www.10000recipe.com/recipe/6885931
# https://www.10000recipe.com/recipe/6883189
# https://www.10000recipe.com/recipe/6881383
# https://www.10000recipe.com/recipe/6881379
# https://www.10000recipe.com/recipe/6881377
# https://www.10000recipe.com/recipe/6881374
# https://www.10000recipe.com/recipe/6881320
# https://www.10000recipe.com/recipe/6880350
# https://www.10000recipe.com/recipe/6880333
# https://www.10000recipe.com/recipe/6879057
# https://www.10000recipe.com/recipe/6879037
# https://www.10000recipe.com/recipe/6878356
# https://www.10000recipe.com/recipe/6878165
# https://www.10000recipe.com/recipe/6877609
# https://www.10000recipe.com/recipe/6877290
# https://www.10000recipe.com/recipe/6876789
# https://www.10000recipe.com/recipe/6876773
# https://www.10000recipe.com/recipe/6876772
# https://www.10000recipe.com/recipe/6876602
# https://www.10000recipe.com/recipe/6876524
# https://www.10000recipe.com/recipe/6876310
# https://www.10000recipe.com/recipe/6876305
# https://www.10000recipe.com/recipe/6875844
# https://www.10000recipe.com/recipe/6875824
# https://www.10000recipe.com/recipe/6875635
# https://www.10000recipe.com/recipe/6874855
#
# url갯수:  41

# %%
##3페이지에 있는 url 크롤링

# 크롬창 띄우기
driver = webdriver.Chrome("./chromedriver.exe")
driver.get("https://www.10000recipe.com/recipe/list.html?q=%EC%B1%84%EC%8B%9D&order=reco&page=3")
time.sleep(3)

dict = {}   # 전체 데이터를 담을 딕셔너리 생성


 # 비건 검색해 나온 레시피 창 url크롤링
url_list = []
title_list = []

count=0

while(count<1):
    count=count+1
    # URL_raw 크롤링 시작
    articles = "a.common_sp_link" # 중간에 띄어쓰기는 .으로 대체, selector는 >로 이동
    article_raw = driver.find_elements_by_css_selector(articles)
    #article_raw[0]

    # 크롤링한 url 정제 시작
    for article in article_raw:
        url = article.get_attribute('href')   
        url_list.append(url)
        print(url)

    # 1초 쉬어 주고,
    time.sleep(1)
print("")
print('url갯수: ', len(url_list))
#print('title갯수: ', len(title_list))

df3 = pd.DataFrame({'url':url_list})
# Out:
# https://shop.10000recipe.com/goods/goods_view.php?goodsNo=1000007266&utm_source=10k_recipe&utm_medium=recipe_search_list&utm_campaign=g%EB%B0%80%EC%8A%A4%EC%9B%90%EB%A7%B5%EC%BD%A9%EB%8B%AC%EC%BD%A9%EC%BD%A9%EA%B3%A0%EA%B8%B0%EC%8A%A4%ED%85%8C%EC%9D%B4%ED%81%AC2%EC%A2%8510%ED%8C%A9
# https://www.10000recipe.com/recipe/6874207
# https://www.10000recipe.com/recipe/6874075
# https://www.10000recipe.com/recipe/6873865
# https://www.10000recipe.com/recipe/6872982
# https://www.10000recipe.com/recipe/6872672
# https://www.10000recipe.com/recipe/6872514
# https://www.10000recipe.com/recipe/6872509
# https://www.10000recipe.com/recipe/6872486
# https://www.10000recipe.com/recipe/6868299
# https://www.10000recipe.com/recipe/6868251
# https://www.10000recipe.com/recipe/6868250
# https://www.10000recipe.com/recipe/6868249
# https://www.10000recipe.com/recipe/6867819
# https://www.10000recipe.com/recipe/6866546
# https://www.10000recipe.com/recipe/6866544
# https://www.10000recipe.com/recipe/6866536
# https://www.10000recipe.com/recipe/6866535
# https://www.10000recipe.com/recipe/6866533
# https://www.10000recipe.com/recipe/6866185
# https://www.10000recipe.com/recipe/6866090
# https://www.10000recipe.com/recipe/6865880
# https://www.10000recipe.com/recipe/6865878
# https://www.10000recipe.com/recipe/6865768
# https://www.10000recipe.com/recipe/6865763
# https://www.10000recipe.com/recipe/6865760
# https://www.10000recipe.com/recipe/6865752
# https://www.10000recipe.com/recipe/6865744
# https://www.10000recipe.com/recipe/6865690
# https://www.10000recipe.com/recipe/6865686
# https://www.10000recipe.com/recipe/6865656
# https://www.10000recipe.com/recipe/6865654
# https://www.10000recipe.com/recipe/6865648
# https://www.10000recipe.com/recipe/6859995
# https://www.10000recipe.com/recipe/6851084
# https://www.10000recipe.com/recipe/6838142
# https://www.10000recipe.com/recipe/6833295
# https://www.10000recipe.com/recipe/6830543
# https://www.10000recipe.com/recipe/6830542
# https://www.10000recipe.com/recipe/6830541
# https://www.10000recipe.com/recipe/6830539
#
# url갯수:  41

# %%
##4페이지에 있는 url 크롤링

# 크롬창 띄우기
driver = webdriver.Chrome("./chromedriver.exe")
driver.get("https://www.10000recipe.com/recipe/list.html?q=%EC%B1%84%EC%8B%9D&order=reco&page=4")
time.sleep(3)

dict = {}   # 전체 데이터를 담을 딕셔너리 생성


 # 비건 검색해 나온 레시피 창 url크롤링
url_list = []
title_list = []

count=0

while(count<1):
    count=count+1
    # URL_raw 크롤링 시작
    articles = "a.common_sp_link" # 중간에 띄어쓰기는 .으로 대체, selector는 >로 이동
    article_raw = driver.find_elements_by_css_selector(articles)
    #article_raw[0]

    # 크롤링한 url 정제 시작
    for article in article_raw:
        url = article.get_attribute('href')   
        url_list.append(url)
        print(url)

    # 1초 쉬어 주고,
    time.sleep(1)

print("")
print('url갯수: ', len(url_list))
#print('title갯수: ', len(title_list))

df4 = pd.DataFrame({'url':url_list})
# Out:
# https://shop.10000recipe.com/goods/goods_view.php?goodsNo=1000007266&utm_source=10k_recipe&utm_medium=recipe_search_list&utm_campaign=g%EB%B0%80%EC%8A%A4%EC%9B%90%EB%A7%B5%EC%BD%A9%EB%8B%AC%EC%BD%A9%EC%BD%A9%EA%B3%A0%EA%B8%B0%EC%8A%A4%ED%85%8C%EC%9D%B4%ED%81%AC2%EC%A2%8510%ED%8C%A9
# https://www.10000recipe.com/recipe/6830538
# https://www.10000recipe.com/recipe/6830537
# https://www.10000recipe.com/recipe/6830536
# https://www.10000recipe.com/recipe/6830535
# https://www.10000recipe.com/recipe/6830533
# https://www.10000recipe.com/recipe/6830531
# https://www.10000recipe.com/recipe/6544516
# https://www.10000recipe.com/recipe/6541231
# https://www.10000recipe.com/recipe/5783153
# https://www.10000recipe.com/recipe/5771964
# https://www.10000recipe.com/recipe/5771941
# https://www.10000recipe.com/recipe/5770303
# https://www.10000recipe.com/recipe/5767976
# https://www.10000recipe.com/recipe/5767868
# https://www.10000recipe.com/recipe/5767692
# https://www.10000recipe.com/recipe/5767610
# https://www.10000recipe.com/recipe/5760789
# https://www.10000recipe.com/recipe/5756199
# https://www.10000recipe.com/recipe/5756194
# https://www.10000recipe.com/recipe/5756103
# https://www.10000recipe.com/recipe/5756100
# https://www.10000recipe.com/recipe/5750775
# https://www.10000recipe.com/recipe/5750737
# https://www.10000recipe.com/recipe/5692743
# https://www.10000recipe.com/recipe/5663069
# https://www.10000recipe.com/recipe/5663034
# https://www.10000recipe.com/recipe/5649770
# https://www.10000recipe.com/recipe/5647308
# https://www.10000recipe.com/recipe/5644125
# https://www.10000recipe.com/recipe/5644093
# https://www.10000recipe.com/recipe/5445969
# https://www.10000recipe.com/recipe/5095088
# https://www.10000recipe.com/recipe/4320378
# https://www.10000recipe.com/recipe/1929739
# https://www.10000recipe.com/recipe/1845427
# https://www.10000recipe.com/recipe/1754791
# https://www.10000recipe.com/recipe/932104
# https://www.10000recipe.com/recipe/724890
# https://www.10000recipe.com/recipe/551172
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"a.next"}
#   (Session info: chrome=92.0.4515.131)
#
#
# url갯수:  40

# %%
#df = pd.DataFrame({'url':url_list})
#크롤링한 레시피 url병합
df = pd.concat([df1,df2, df3, df4], ignore_index=True)

# %%
df #병합된 dataframe확인
# Out:
#                                                    url
# 0    https://shop.10000recipe.com/goods/goods_view....
# 1           https://www.10000recipe.com/recipe/6918300
# 2           https://www.10000recipe.com/recipe/6877875
# 3           https://www.10000recipe.com/recipe/6959723
# 4           https://www.10000recipe.com/recipe/6891713
# ..                                                 ...
# 158         https://www.10000recipe.com/recipe/1845427
# 159         https://www.10000recipe.com/recipe/1754791
# 160          https://www.10000recipe.com/recipe/932104
# 161          https://www.10000recipe.com/recipe/724890
# 162          https://www.10000recipe.com/recipe/551172
#
# [163 rows x 1 columns]

# %%
df.to_csv("10000_recipe_url.csv", encoding='utf-8') #url모은 dataframe csv파일로 따로 저장

# %%
###############################################

# %%
url_load=pd.read_csv("10000_recipe_url.csv", encoding='utf-8') #url 파일 불러오기


num_list = len(url_load)

print(num_list)
url_load

dict = {}    # 전체 크롤링 데이터를 담을 그릇

number = 162  # 수집할 글 갯수 정하기

path = "./chromedriver.exe"

# 수집한 url 돌면서 데이터 수집
for i in tqdm(range(0, number)):
    # 글 띄우기
    url = url_load['url'][i]
    driver = webdriver.Chrome(path)  # 윈도우는 "chromedriver.exe"
    driver.get(url)   # 글 띄우기
    
    # 크롤링
    
    try:
     
        target_info = {}  # 개별 레시피 내용을 담을 딕셔너리 생성

        # 제목 크롤링 시작
        overlays = "div.view2_summary.st3"                                 
        tit = driver.find_element_by_css_selector(overlays)          # title
        title = tit.text
    
        # 재료 크롤링 시작
        overlays = "div.ready_ingre3"                                 
        ingre = driver.find_element_by_css_selector(overlays)          # title
        ingredient = ingre.text
    
        # 사진(pic) 크롤링
        overlays1 = "div.centeredcrop>img"
        img = driver.find_element_by_css_selector(overlays1)# 사진 선택
        #print(img)
        pic = img.get_attribute('src')      # 사진 url 크롤링
        pic
        #print(pic)

        # 내용 크롤링
        overlays = "div.view_step"                                 
        contents = driver.find_elements_by_css_selector(overlays)    # contents
        #print(contents)

        content_list = []
        for content in contents:
            content_list.append(content.text)
 
        content_str = ' '.join(content_list)                         # content_str

        # 글 하나는 target_info라는 딕셔너리에 담기게 되고,
        target_info['title'] = title
        target_info['ingredient'] = ingredient
        target_info['pic']=pic
        target_info['content'] = content_str

        # 각각의 글은 dict라는 딕셔너리에 담기게 됩니다.
        dict[i] = target_info
        time.sleep(1)
        
        # 크롤링이 성공하면 글 제목을 출력하게 되고,
        print(i, title)

        # 글 하나 크롤링 후 크롬 창을 닫습니다.
        driver.close()
        
    except Exception as e:
        print(e,'This page is error :',i)
        driver.close()
        time.sleep(1)
        continue
        
    # 에러나면 현재 크롬창을 닫고 다음 글(i+1)로 이동합니다.
    
    # 중간,중간에 파일로 저장하기
    if i == 30 or 50 or 80:
        # 판다스로 만들기
        import pandas as pd
        result_df = pd.DataFrame.from_dict(dict, 'index')

        # 저장하기
        result_df.to_excel("10000_recipe_채식.xlsx", encoding='utf-8-sig')
        time.sleep(3)

print('수집한 글 갯수: ', len(dict))
#print(dict)

# 판다스로 만들기
import pandas as pd
result_df = pd.DataFrame.from_dict(dict, 'index')
result_df

#result_df.to_excel("blog_content.xlsx", encoding='utf-8-sig')
# Out:
# 163
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=162.0), HTML(value='')))
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.view2_summary.st3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 0
# 1 오늘 저녁은 채식위주로??? 에어프라이어표 버섯채소구이 ★
# 냉장고에 있는 칭구들~! 에어프라이어로 들어왓~!
# 또 내입으로 들어왓~! 샐러드에 얹어 먹으면 너무 좋겠는걸 ?
# 세상의 모든 레시피 만개의레시피
# 3인분 20분 이내 초급
# 2 녹차파운드케이크 : 노버터,통밀가루 나름 채식베이킹
# 통밀가루를 이용해 제가 좋아하는 녹차 디저트를 만들었어요. 노버터, 노밀가루라 다이어트 하는 분들에게도 좋은 채식베이킹 입니다.
# 6인분 이상 90분 이내 중급
# 3 매콤 달콤한 팽이버섯 양념구이.(버섯요리, 밥반찬, 채식.)
# 묶음으로 팔아서 팽이버섯을 어쩔 수 많이 구매 했을 때 한 번에 맛있게 해결하기 위해 만들어 본 메뉴인데 밥 반찬으로 딱 이더라고요~그래서 레시피를 공유해봅니다^^
# 3인분 10분 이내 아무나
# 4 다이어트 채식주의자를 위한 치커리 샐러드/겉절이
# 더워진 날씨 짧아진 옷차림~ 다이어트를 위한 또는 채식자를 위한 치커리 샐러드랍니다. 야채뿐인 샐러드이지만 새콤달콤한 소스로 입맛엔 제격~ 부담이 가지않는 샐러드예요.
# 2인분 10분 이내 초급
# 5 한그릇요리, 채식버섯리조또, 두유버섯리조또만들기
# 우유나 생크림, 버터 대신 두유를 이용해서 더욱더 담백하고 건강하게 즐길수 있는 한그릇요리 '두유버섯리조또'입니다.
# 2인분 30분 이내 아무나
# 6 채식: 가지 된장 덮밥
# 삼시세끼 에셰프의 가지 덮밥을 보고 만들었어요.
# 된장으로 양념을 하니 중식느낌이 더 나네요.
# 만들기는 뚝딱인데, 맛이 좋아서 가족들도 칭찬한 메뉴입니다.
# 1인분 10분 이내 아무나
# 7 채식을 위한 고기뺀 '잡채';당면이 불지 않는 비법
# 채식식단에 [잡채]가 빠질 수 없죠.
#
# 고기 뺀 잡채는 2% 아쉬운 맛이지만,
# 잡채는 어떻게 먹어도 맛진것 같습니다.
#
# 오늘은
# 시간이 지나도 불지 않는 잡채 만들기 비법도 함께 알려드릴께요.
# (방송 생생 정보통 황금비율에서 배웠습니다)
#
# 시간이 지나도 면이 불지 않아서 도시락용으로도 좋습니다.
# 4인분 60분 이내 아무나
# 8 채식베이킹 시금치롤
# 시금치를 갈아 넣어 아침식사 대용 빵으로 좋은 시금치롤빵입니다.
# 6인분 이상 2시간 이상 중급
# 9 고기없이도 충분히 맛있는 쫄깃한 버섯 잡채 #비건(채식)레시피
# 요즘 건강을 생각해서 채식을 하는 사람들이 많아지고 있습니다. 그런 분들에게 영양가도 풍부하고, 맛도 좋은 버섯잡채를 추천합니다. 고기가 없어도 쫄깃한 버섯의 식감이 고기 못지않게 맛있습니다.
# 그리고 번거롭게 채소를 따로 볶고 면을 삶는 과정이 없이 팬 하나로 간편하게 만들 수 있는 레시피입니다.
# 2인분 60분 이내 초급
# 10 [비건채식] 새송이버섯 소금구이
# 간단하게 새송이버섯 소금구이 만들어 저녁 반찬했어요.
# 새송이버섯, 소금, 후추, 들기름으로 만든 초간단 요리지만
# 들기름과 새송이버섯 어우러져 후각과 미각을 자극하네요.
# 4인분 5분 이내 아무나
# 11 쫄깃한 두부와 아삭한 장아찌로 만든 착한 김밥 #비건(채식)레시피
# 건강과 환경을 동시에 챙길 수 있는 채식을 하는 분들이 많아지고 있습니다. 김밥도 계란이나 햄을 넣지 않고 두부와 장아찌를 넣어 맛있게 만든 착한 김밥에 대한 관심도 늘어나고 있습니다. 오늘은 착한 김밥을 만들어 보았습니다.
# 3인분 60분 이내 초급
# 12 2그릇 순삭 가능!! 간단하게 매콤 잡채 만드는 법, 별미 잡채, 잡채밥, 채식
# 별식잡채를 만들었습니다. 매콤 잡채! 간단하면서도 아주 맛있답니다. 밥은 저만치 밀어버리고 잡채만 2그릇 이상은 클리어! 가능합니다. 밥 위에 올리면 잡채밥~
# 4인분 30분 이내 아무나
# 13 [비건채식] 간단하게 가지구이 만들었어요.
# 신랑이 밭에서 따 온 가지로 구웠어요.
# 4인분 10분 이내 아무나
# 14 [비건채식] 마파두부
# 아침에 비건채식 마파두부 만들어
# 마파두부덧밥으로 먹었어요.
#
# 막둥이 도시락도 싸주고요.
#
# 색상 참 예쁘죠.
# 맛도 너무 맛있었네요.
#
#
# 6인분 이상 30분 이내 아무나
# 15 들깨미역국:멸치 한마리도 출입금지...완전한 채식미역국
# 소고기와 멸치육수도 없이
# 쌀뜨물과 미역불린물을 국물베이스로 하여
# 들기름과 들깨로 맛을 더한 완전채식미역국을
# 끓여보았어요:그 맛은...소고기도 멸치육수도
# 아쉬울 것 없는 아주 맛있는 미역국이었답니다
# 아, 그리고 국물양에 비해 미역양을 많이 잡은
# 건더기가 푸짐한 미역국이기도 합니다
# 6인분 이상 60분 이내 초급
# 16 [비건채식] 콩나물불고기 대신 콩나물언리미트~
# 언리미트 이벤트에 당첨되어서
# 돼지고기 대신 언리미트 콩단백을 넣고 비건채식으로 요리를 만들어보았어요~
#
# 저는 언리미트에서 나온 콩단백이 얇은 대패삼겹살이나 제육볶음용 고기와 '식감'이 유사해서 콩나물불고기를 만들기에 적격일거 같더라구요. 제육볶음도 양념과 야채만 달리해서 만들어봐도 좋을 것 같습니다.
#
# 첫 레시피 등록이네요~
# 맛있게 드세요 :)
# 4인분 30분 이내 초급
# 17 채식 라따뚜이
# 프랑스 요리중 하나인 라따뚜이를 고기 없이 건강한 채식요리로 만들어 봅니다.
# 3인분 60분 이내 중급
# 18 [비건채식]무오신채 가을 무생채
# 가을 무가 역시 맛있네요.
# 물도 많이 들어 있고 달콤하네요.
# 무오신채로 만들었어요.
# 6인분 이상 15분 이내 아무나
# 19 채식: 고추장 비빔장 만들기
# 시중에서 파는 비빔장 말고, 집에서 간단하게 비빔장 만들어서 먹어요.
# 해조류 쌈 싸먹을 때, 비빔국수 먹을 때 비빔장만 딱 넣으면 끝/
# 2인분 5분 이내 아무나
# 20 가벼운 느낌의 크림스파게티같아요~ 두부스파게티,채식스파게티
# 고기없이 두부를 으깨 볶아주면서 만든 두부스파게티입니다. 묵직한 크림스파게티가 아닌 가벼운 느낌의 스파게티, 소스와 면을 숟가락에 올려 한입에 드셔보세요.
# 1인분 15분 이내 초급
# 21 보기에도 아름다운 채식 구절판 만들기
# 손은 많이 가지만
# 손님 초대상에 내놓으면
# 시각과 미각을 만족시킬 수
# 있는 구절판을 만들어 봅니다
# 6인분 이상 60분 이내 아무나
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.ready_ingre3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 22
# 23 깻잎순 된장 무침.(나물반찬, 채식, 건강식.)
# 한 철만 반짝 왔다가는 깻잎순을 보통은 멸치 넣고 간장 양념에 조려 먹지만 나물로 무쳐도 향긋하고 담백하니 맛있답니다. 레시피도 간단하고 맛있는 메뉴를 소개해요~
# 2인분 10분 이내 아무나
# 24 알록달록 예쁘고 맛있는, 착한 채식(비건)초밥 #참드림쌀레시피
# 온가족이 함께 먹는 브런치 메뉴로 채식초밥을 만들어보는 건 어떨까요? 알록달록 예쁜 모양과 컬러, 여름철에도 안심하고 먹을 수 있는 새콤하고 아삭한 채소와 쫄깃하고 감칠맛나는 버섯이 부드러우면서도 쫀득쫀득 맛있는 토종쌀로 지은 밥과 만나 다이어트에도 좋은 착한 초밥이되었지요.
# 3인분 60분 이내 중급
# 25 다이어트 채식요리- 산뜻한 토마토 카레 만들기
# 건강하면서도 가볍게 즐기기 위해 고기는 빼고 토마토를 듬뿍 넣고 카레를 만들어 보았어요.
# 일반 카레보다 좀 더 가볍고 산뜻한 맛이랍니다.
# 6인분 이상 20분 이내 초급
# 26 채식주의자도 OK! 고기 없이도 맛있는 비건 만두전골
# 고기 없는 만두전골이라니... 말이 돼?!
# 그런데 그것이 실제로 일어났습니다!
#
# 10가지 채소로 고기 없이도 맛있는 그린가든만두,
# 영국 비건협회에서 인증받은 채황라면!
#
# 담백하고 깔끔하니 속도 가볍네~
# 2인분 30분 이내 아무나
# 27 정식품 콩국물을 활용한 채식 비건만두스튜
# 정식품의 베지밀, 콩국물은 유당불내증을 많이 겪는 한국인에게
# 최적화된 식품으로 글루텐프리, 채식요리와 매우잘 어울리며
# 활용도가 높아, 비건푸드로 활용해 보았습니다.
# 1인분 15분 이내 아무나
# 28 (코로나극복)부추두부들깨탕:혼밥러,다이어터,채식주의자의 영양식
# 고기없이 채식으로도 할 수있는 몸보신요리에요. 채식주의자가 아니라도 넘 좋은 보양식이에요.
# 1인분 20분 이내 초급
# 29 채소찜된장스프:채식몸보신요리
# 채소찜을 한 후 된장을 넣어 끓인 채소찜된장스프는 아들에게는 밥과 함께 먹는 채소된장국이었고 나에게는 영양넘치는 다이어트스프,오늘의 섭생용이었어요.
# 2인분 30분 이내 중급
# 30 정식품 콩국물 채식 산마그라탕
# 영양이 많은 산마를 정식품 진한 콩국물에 향신료 넣어서 조려내고
# 오븐 구워내어 건강한 채식 그라탕을 만들어 보았습니다.
# 1인분 90분 이내 중급
# 31 정식품 콩국물소스 채식 푸주 파스타
# 20년 가까이 채식을 하고 있어서 평소에 새로은 채식 식재료에 관심이 많아 콩으로 만든 푸주를 정식품 진한 콩국물에 불려서 콩이 주재료가 되는 건강하고 다이어트식인 채식 퓨전 파스타를 만들어 보았습니다.
# 1인분 2시간 이상 중급
# 32 퀴노아 채식 샐러드, 간단하고 건강하게
# 덥고 입맛도 없고 더운 요리하기 싫고 건강하게 먹고싶은 날.
# 퀴노아 샐러드로 입맛도 찾고 건강도 찾았답니다. 제가 가끔 샐러드 먹고 싶으면 퀴노아 샐러드를 주로 만드는데 이번에는 고기빼고 채식으로 만들었어요.
# 2인분 30분 이내 아무나
# 33 두부로 만든 채식 카프레제 샐러드♡죄의식 없이 배부르게 먹자!!!
# 베란다에서 키우고 있는 바질이 훌쩍 자랐기에 카프레제 샐러드를 만들어봤어요~모짜렐라치즈를 쓰면 에피타이저로 한두점밖에 먹을 수가 없는데, 두부를 써서 죄의식 없이 잔뜩 먹었답니다~^^
# 2인분 15분 이내 초급
# 34 치자두부소보루톳밥과 미나리된장양념장 채식
# 봄스러운 밥
# 톳밥에 계란대신 두부에 치자물을 들여서 고소한맛에 미나리 양념장에 비벼 먹으면 입안은 봄이되는 밥
# 4인분 60분 이내 아무나
# 35 초간단♡호박죽♡단호박두유죽♡채식주의@단호박두유타락죽~
# 오래전 헤어진 남친이 그해 추석에 단호박을 보내준 일이 있었어요. 아무런 메시지도 없이...무슨 뜻이었을까요? 내가 너무 단호(박)하게 헤어지자고 해서 원망하는 마음을 담은걸까요? 어떤 마음을 담았던 간에 단호박은 엄청 달콤했었죠~^^
# 단호박은 맛도 좋고 색도 좋고 건강에도 좋은 일석삼조 식재료인데 요리했을 때 제일 맛있는건 죽이나 스프인 것 같아요. 오늘 끓인 죽은 타락죽 스타일인데 우유 대신 두유를 넣었어요. 채식하는 분들에게도 좋은 레시피가 되겠죠? ^^
# 2인분 15분 이내 초급
# 36 두부약고추장:채식,저염식 밑반찬
# 소고기 대신 두부를 넣어 고추장양념에 볶은 저염식 두부고추장볶음이자 채식두부약고추장이에요
# 4인분 15분 이내 아무나
# 37 [암예방레시피] 채식주의자를 위한 무염 야채 그라탕!
# 항암에 좋은 폴리페놀이 풍부한 가지, 베타 카로틴이 많은 단호박, 베타 글루칸이 풍부한 버섯,글리시테인이 포함된 콩크림을 조합하여 만든
# 항암에 좋고 소금을 전혀 사용하지 않아서 더욱 건강하고 몸에 좋은
# 채식 주의자들을 위한 레시피 입니다.
# 야채의 단맛과 두유크림의 단백함을 마늘과 바질의 향으로 엣지있게 잡았습니다.
# 이것보다 더 항암에 좋으면서도 건강할순 없는 완벽한 영양소를 가진 레시피는 없다고 생각합니다!
# 색감이 고아서 보기에 좋은건 덤입니다!
# 2인분 30분 이내 초급
# 38 [암예방레시피] 귀리버섯패티를 이용한 채식 샌드위치
# 귀리가루위 갈은 버섯을 넣어 반죽해서 패티를 만들었는데 엄청 맛있는 채식 샌드위치가 되었어요
# 고기없이 고기맛과 식감이나는 패티
# 야채는 냉장고에 있는 재료로했어요
# 상추가 없어서 단배추잎으로 했는데 하나도 거슬리는것 없었어요
# 2인분 30분 이내 아무나
# 39 채식 공심채 퀘사디아
# 호박꽃 퀘사디아를 만들며 지금 제철인 공심채도 볶아 넣으면 좋을거 같아 공심채를 주 재료로 만들어 봅니다.
# 1인분 30분 이내 초급
# 40 채식 양파 퀘사디아
# 양파 농가를 돕는다고 은행에서 양파 나눔을 해서
# 받아 온 양파로 새로운 양파요리를 만들어 봤습니다.
# 1인분 30분 이내 중급
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.view2_summary.st3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 41
# 42 채식 감자피자
# 밀가루 도우 없이 가지를 밑에 깔고서 만든 피자가 꽤 괜찮아서
# 이번에는 직접 키운 하지감자를 가지대신에 피자로 만들어 봅니다.
# 2인분 30분 이내 중급
# 43 도시락으로도 좋은 수미네반찬 화제의 레시피 이상민 두부김밥 만들기(비건김밥,채식김밥,두부요리)
# 오늘은 지금 화제의 레시피죠? (아...그래야 되는데..)
# 수미네 반찬에 나왔던 이상민님의 두부김밥을 만들어봤습니다.
# 정말 별다른 재료 필요없이 두부와 청양고추,
# 그리고 데리야끼 소스와 마요네즈만 있으면 되는데요
# 만드는 방법도 정말 간단해서 요리 초보분들도 집에서 따라하기 정말 쉽습니다.
# 1인분 30분 이내 초급
# 44 #남은나물활용요리 #나물김밥만들기 #베지테리안 #채식주의자를위한 나물김밥 #남은닭갈비와나물의만남!!!
# 대보름이 지난지도 꽤 되었는데 물론 그전에 미리 만들어서 먹은 나물김밥입니다.
#
# 나물로 비빔밥도 해 먹고 그냥도 먹고 다 했는데도 남아서
#
# 이번에는 채식주의자들을 위한 나물김밥을 만들어 보았어요.
#
#
#
# 예전 유럽여행을 갈때에 서점에서 구입한 베지테이언음식 레시피가 담겨진 책에서도 보았는데
#
# 나물을 넣고 만든 김밥이 있더라구요. 거기에서 된장덮밥도 있어서 해보기도 했죠. ㅎㅎ
#
# 나물은 냉장고에 보관한다고 해도 그 수명이 그리 오래가지 못하기 때문에
#
# 빨리 빨리 먹지 않으면 금방 쉬게 되지요. 그래서 김밥으로 변신시켜 보았습니다.
#
#
#
# 베지테이언을 위한 나물만 넣고 만든 나물김밥과
#
# 난 고기는 죽어도 먹어야 한다고 하시는 분들에게는 남은 닭갈비를 넣고 만든
#
# 나물닭갈비김밥도 만들었습니다.
#
#
#
# 어찌보면 남은 재료의 활용 파티네요 ㅎㅎ
# 4인분 20분 이내 아무나
# 45 캐슈넛 버터 쉽게 채식버터 만들기
# 오늘은 노버터, 노설탕, 노오일의 건강한 채식버터를 소개해볼께요. 만들기도 너무 간단해서 쉽게 만들수 있구요, 건강하게 먹을수 있는 스프레드라고 생각하시면 될것 같아요. 심심한 크래커나 토스트한 빵과 잘 어울려요~ 건강한 채식버터 캐슈넛버터를 만들어보아요~
# 4인분 15분 이내 아무나
# 46 비건(vegan)/채식베이킹 "바나나병아리콩스콘"
# 달걀, 우유, 버터 등 동물성 재료가 일체 들어가지 않는 건강한 스콘이에요. 영양가 많은 바나나와 단백질이 가득 든 병아리콩등 건강한 우리밀을 사용하여 간단한 식사로 드시기에도 손색이 없답니다^^
# 6인분 이상 30분 이내 아무나
# 47 채식 두부 동그랑땡, 간모도키 만들기
# 고기없이, 계란없이도 맛있게 두부 동그랑땡 만들 수 있는 것 아셨나요? ^^
# 고기에 예민한 분들도 맛나게 드실 수 있습니다~
# 이 레시피는 타파웨어의 스무디차퍼와 함께 합니다~ ^^
# http://www.tupperwaremall.co.kr/
# 4인분 30분 이내 중급
# 48 바삭바삭 채식주의자를 위한 부추전
# 오로지 집에있는 부추와 채소들을 이용해도 맛있는 전을 부쳐먹을 수가 있어요.
# 2인분 10분 이내 초급
# 49 여름제철채식반찬: 두부오이볶음
# 어릴 때 엄마는 소고기와 오이를 함께 볶아서 주시곤 했는데 나는 그걸 채식요리로 응용하여 두부를 오이와 함께 볶았다.
# 3인분 30분 이내 중급
# 50 <여름제철밑반찬>가지약고추장/ 채식고추장볶음
# 여름 흔한 채소 중 하나인 가지를 소고기 대신 넣은
# 채식 약고추장을 만들었어요. 더위에 지친 입맛을 살릴 여름 밑반찬으로 추천합니다.
# 4인분 30분 이내 중급
# 51 [비건채식]음나무어리순(개두릅) 두부무침
# 정원에 있는 한그루 음나무, 봄이면 어린순을 내어주네요.
# 4인분 15분 이내 아무나
# 52 #윤식당 #채식비빔밥만들기 #조미유부를 사용하면 간단하게 만들 수 있는 채식비빔밥
# 조미유부를 이용해서 간단하게 간장양념없이 만들 수 있는 채식비빔밥을 만들어 볼까요. 집에 있는 나물반찬과 함께 각종 채소를 볶아서 고명으로 사용하고 거기에 고추장이 아닌 맛간장을 넣고 비벼서 먹는 채식비빔밥!!!
# 2인분 30분 이내 아무나
# 53 [비건채식] 이색 나물 : 어린신선초나물, 콩나물
# 밭에서 어린 신선초를 따고
# 콩나물은 구입해
# 나물을 만들었어요.
# 어린 신선초라 부드럽고 상큼하니 맛있네요.
# 6인분 이상 15분 이내 아무나
# 54 [비건채식] 어린 머위나물
# 따뜻한 봄날 어린 머위를 밭에서 따서
# 봄나물 머위나물 무쳤어요.
# 봄내음 물씬 나죠.
# 4인분 10분 이내 아무나
# 55 채식: 곰피 쌈밥
# 곰피라는 해조류에 대해 들어보신 적 있으신가요?
# 다시마나 미역에 비해 비린 냄새가 거의 없는 맛있는 해조류랍니다.
# 맛있게 쌈밥으로 즐겨보세요.
# 1인분 5분 이내 아무나
# 56 채식: 꼬시래기 무침
# 해풍과 햇빛으로 건조시킨 바다의 자연산 국수, 꼬시래기를 다양한 채소와 함께 맛있게 무쳐먹어요. 막국수 느낌인데, 칼로리는 낮아서 다이어트 한 끼로도 좋습니다.
# 2인분 10분 이내 초급
# 57 [비건채식] 도토리묵 만들었어요.
# 도토리묵이 칼로리도 낮고
# 포만감을 있어
# 도토리묵을 구입해 먹다가
# 도토리묵가루를 구입해 만들어 봤어요.
# 탱글탱글하니 맛있네요.
# 6인분 이상 90분 이내 아무나
# 58 [비건채식 소세지만두볶음]
# 막둥이 오늘 급식메뉴가 소세지볶음이라
# 비건채식 소세지만두볶음 했네요.
# 3인분 15분 이내 아무나
# 59 [비건채식 볶음우동]
# 막둥이 급식 메뉴중 볶음우동이 있어
# 비건채식 볶음우동 만들어 보냈네요.
# 3인분 30분 이내 아무나
# 60 [비건채식 간단한 두부새송이볶음]
# 점심을 준비하면서
# 간단하게 만들어 보았네요.
# 4인분 10분 이내 아무나
# 61 [비건채식 콩살로만고구마조림]
# 막둥이 급식메뉴중 ○고구마조림가 있어
# 비건채식 콩살로만고구마조림 만들었어요.
# 6인분 이상 30분 이내 아무나
# 62 채소밀쌈말이 - 채식요리, 초대요리
# 여러가지 채소를 채썰어서 밀쌈으로 돌돌 말아 먹는 요리로, 손님초대나 특별한 날에 좋은 요리입니다.
# 4인분 60분 이내 중급
# 63 채식 사시미 만들기
# 채식을 하기 전에 즐기던 생선 사시미를 채식으로 만들어 보았습니다.
# 2인분 2시간 이상 중급
# 64 채식 올리브 페스토 파니니
# 질 좋은 올리브가 구해져 올리브로 페스토를 넣은 파니니를 만들어 보았습니다.
# 2인분 30분 이내 초급
# 65 무오신채 채식 능이버섯 육개장
# 고기 대신에 능이버섯을 넣고서 고추가루도 넣지 않고 끓여본 건강한 채식 육개장을 소개 합니다.
# 면역력이 떨어져서 고추가루를 먹어서 안 되시는 분들에게 아주 좋은 건강식 입니다.
# 3인분 60분 이내 초급
# 66 채식 호박 & 토란 샐러드
# 텃밭에서 뜯어 온 늙은 호박과 요즘 제철인 토란으로 만들어 본 샐러드를 소개를 합니다.
# 2인분 30분 이내 초급
# 67 채식: 볶음 쌀국수(팟타이) 샐러드
# 샐러드와 곁들여 먹으면서 배도 든든한 한 끼.
# 볶음 쌀국수 요리하기 정말 쉬워요.
# 1인분 10분 이내 초급
# 68 채식 자연산 곰버섯 퀘사디아
# 가을철 강원도 산에서 구해진 자연산 곰버섯으로 이번에는 언젠가 멕시코에서 옥수수 곰팡이 버섯으로 만든 퀘사디아를 보고서 비슷한 비주얼로 만들어 보기로 했습니다.
# 2인분 30분 이내 초급
# 69 채식: 담백하게 끓인 두부 카레
# 기름으로 볶은 요리는 이제 질려서, 담백한 카레를 끓였습니다. 고기 대신 두부를 넣어서 부드러움은 높이고 칼로리는 낮추고 1석 2조이죠. 기름 한 방울 넣지 않은 담백한 카레로 든든하게 건강하게 한 끼 드세요.
# 4인분 30분 이내 아무나
# 70 참깨쿠키 / 파슬리참깨크래커 : 채식베이킹
# 요즘 다이어트 시도 중 이라 채식베이킹 쿠키 만들어볼게요. 쿠키는 먹고 싶지만 살 찔 까봐 걱정이 되어 노설탕, 노버터, 노계란으로 만든 어마어마한 채식베이킹 입니다.
# 4인분 60분 이내 아무나
# 71 채식: 동그랑땡(비지전)
# 두유를 직접 만들다 보면, 많은 양이 비지가 생깁니다.
# 버리기엔 아깝고, 뭔가 활용할 곳이 없을까? 고민하다가 만든 반찬입니다.
# 고기가 없어도 맛있는 반찬 만들어 보세요.
# 반죽을 한 번 만들어 두었다가 먹기 전에 부쳐 먹으면 편리하죠.
# 도시락 반찬으로도 좋습니다.
# 6인분 이상 30분 이내 중급
# 72 [비건채식] 베지비엔나소세지볶음
# 베지비엔나소세지로 간단하게 고추가루 넣어 볶아 보았어요.
# 4인분 15분 이내 아무나
# 73 [비건채식] 베지프랑크야채볶음이에요.
# 비건으로 베지프랑크야채볶음 만들었어요.
# 6인분 이상 30분 이내 아무나
# 74 당근호두머핀 만들기 : 채식베이킹
# 별다방 당근케익을 참 좋아하는데 다이어트를 위해 채식베이킹을 해보기로 결심하고 만들어본 레시피입니다. (12-14개 만들 수 있어요)
# 4인분 90분 이내 아무나
# 75 채식요리의 기본 채수 만들기
# 아침저녁으로 날씨가 쌀쌀해져
# 따뜻한 음식이 생각나는 요즘
# 국이나 찌개를 맛있고 간단히 끓일 수
# 있게 채수를 만들어 봅니다
# 6인분 이상 60분 이내 아무나
# 76 채식: 감자껍질칩
# 요리를 하다보면 많은 음식물 쓰레기가 생겨버리죠.
# 하지만, 잘 활용하면 맛좋은 간식으로 만들 수 있어요.
#
# 감자의 영양은 통째로 다 먹고, 버리는 쓰레기는 줄이고, 건강한 간식도 만들고!
# 1석3조의 간단 레시피입니다.
# 1인분 10분 이내 아무나
# 77 채식: 집에서 만드는 두유
# 채식을 하다보면 우유를 대체 할 수 있는 음료를 찾게 됩니다.
# 하지만 시중에 판매하는 두유는 너무 달아서 제 입맛에 맞지 않더라고요.
# 그래서 직접 만들어본 두유.
#
# 요리 과정에 정성이 들어가긴 하지만 그만큼 신선하고 믿을 수 있어 좋아요.
# 4인분 60분 이내 중급
# 78 채식: 찬밥으로 만드는 라이스 밀크
# 우유만 마시면 속이 꾸륵꾸륵할 때가 많죠.
# 채식을 하다보니 대안 우유를 찾게 되는데요.
#
# 집에 있는 찬밥으로 간단하게 휘릭 만드는 라이스밀크.
# 4인분 10분 이내 아무나
# 79 채식: 유부 볶음밥
# 채식 볶음밥 간단하게 만들어봐요. 담백하게 건강하게 채식으로 한 끼 뚝딱.
# 1인분 5분 이내 아무나
# 80 채식 가지 오븐구이
# 오븐만 있으면 간단하게 해 먹을수 있는 가지 오븐요리를 소개 합니다.
# 2인분 90분 이내 초급
# 81 [비건채식] 갈릭올리브오일 파스타를 만들었어요.
# 큰 아들이 좋아하는 파스타~~~
# 이번에는 비건채식 갈릭올리브오일 파스타 만들어 봤어요.
# 간단하게 만들어 먹을 수 있네요.
# 맛도 좋고요.
# 4인분 30분 이내 아무나
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.view2_summary.st3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 82
# 83 고기 없으면 맛 없다고?! 맛있는 채식요리 best5
# 건강을 생각하며 채식을 하게 된 당신!
# 먹고싶은 요리는 많지만 레시피를 모른다고~??
# 건강과 맛 둘다 챙기는 맛있는 채식 레시피 대!공!개!@_@
# 2인분 60분 이내 아무나
# 84 채식 감자커리 라이스
# 채식주의자로써 시중에 판매하는 커리중에 동물성이 없는 커리를 구하기 어려운 실정이라 지난번에 만들어 두었던 마살라로 만들어 본 커리를 소개 합니다. http://blog.naver.com/imsckim/220670966684
# 3인분 30분 이내 중급
# 85 채식 아욱 파스타
# 아욱 특유의 매력적인 향을 살려서 파스타를 만들어 보니 의외로 괜찮아 소개를 합니다.
# 2인분 15분 이내 초급
# 86 채식주의자들을 위한 건강한 맛 '머시룸 타코'
# 채식주의자들을 위한 비건요리 '머쉬룸 타코'
# 씹는 식감을 위해 고기대신 버섯이 들어가 영양만점! 밋밋한 맛을 보완하기 위해 페퍼론치노와 라임을 넣어 살짝 매콤하면서 상큼한 맛이 여름철 잃어버린 입맛을 되찾아 줍니다.
# 2인분 30분 이내 초급
# 87 항생제 위험 없는 채식 계란찜
# 완전식품으로 영양이 많은 계란이지만 항생제의 위험이 늘 있는 식품이고 요즘에 채식을 하시는 분들이 많고 다이어트 식으로도 손색이 없는 영양이 많은 산마로 계란찜을 만들어 봤습니다.
# 2인분 30분 이내 중급
# 88 채식 브로콜리 생면 파스타
# 세몰리나 듀럼밀로 만들어 본 파스타 생면으로 만들어 본 쫄깃한 브로콜리 생면 파스타
# 1인분 30분 이내 중급
# 89 채식 바질 냉콩 파스타
# 날씨도 더워져서 여러가지 콩에 바질을 넣어 만든 냉 소스로 해서 만들어 먹는 냉파스타 .
# 2인분 30분 이내 중급
# 90 채식 루꼴라샐러드
# 루꼴라와 대추토마토에 바질오일로 간단히 만들어 본 샐러드
# 2인분 15분 이내 아무나
# 91 채소된장덮밥:된장짜장/백짜장/냉파요리/저수분채식요리/한그릇요리
# 춘장 대신 된장을 볶아만드는 백짜장/된장짜장을
# 고기없이 냉장고속 자투리채소로만 만들어 보았어요:
# 자극적이지 않고 슴슴한 것이 건강한 채식요리라는
# 생각이 들었어요...카레라이스가 식상할 때
# 혹은 춘장이 없을 때 한번 만들어 보시길 바래요
# 2인분 30분 이내 초급
# 92 [비건채식]무쇠냄비에서 비건채식 콩살로만찜
# 무쇠냄비에서 비건채식 콩살로만찜했네요.
# 6인분 이상 30분 이내 아무나
# 93 [비건채식] 봄나물 원추리나물
# 봄나물인 원추리나물 무쳤어요.
# 상큼하고 달콤하네요.
#
# 봄에는 상큼한 나물을
# 여름에는 아름다운 꽃을 보여주는 원추리이에요.
# 4인분 15분 이내 아무나
# 94 [ 비건채식 ] 표고버섯 밑둥조림
# 생표고버섯 표고버섯이 많이 자랐어요.
# 키워서 먹고
# 썰어 말려 보관하고요.
#
# 표고버섯을 밑둥과 분리하여
# 썰어 햇빛에 말리고요.
# 밑둥은 조렸어요.
# 6인분 이상 30분 이내 아무나
# 95 채식 감자면으로 [비건채식] 탄탄면을 만들어 먹었어요
# 백선생의 집밥을 참고해 채식 감자면으로 비건채식 탄탄면을 만들어 먹었어요. 땅콩맛이 나며 맛있었네요.
# 2인분 10분 이내 아무나
# 96 [비건채식] 야채주먹밥
# 막둥이 현장학습가는 날~~~
#
# 몸이 좋지 않아
# 김이 소화가 잘 안되는 관계로
#
# 김밥대신 주먹밥을 만들었어요.
#
# 아침도 맛있게 먹고
# 점심도시락으로 가져갔어요
# 2인분 15분 이내 아무나
# 97 비건채식 허브비빔밥
# 정원과 밭에서 갓 딴 채소와 허브, 구운 얇은 두부, 양념장과 씨앗견과류를 얹어 만든 허브꽃 비빔밥
# 입에 넣기가 미안하네요.
# 6인분 이상 30분 이내 아무나
# 98 [비건채식]러스크 만들었어요.
# 과발효된 식빵이 만들어져 먹기에 거북했는데
# 비건채식 러스크 만들었더니 모두 맛있게 먹을 수 있네요.
# 먹다 남은 식빵으로 만들어 보세요.
# 바삭바삭하고 달콤하고 고소하네요.
# 6인분 이상 15분 이내 아무나
# 99 [비건채식]우리밀로 만든 채식 청정면 먹었네요.
# 채식라면에 감자, 표고버섯, 미니양배추, 두부, 콩나물, 고추가루을 넣어 끓여 푸짐하게 넣어 맛있게 먹었네요.
# 2인분 15분 이내 아무나
# 100 [비건채식] 비빔당면을 만들어 봤어요.
# 23년전에
# 큰 아들 가졌을때 먹고 싶어
# 국제시장의 당면가게에서 먹었던 것이
# 생각나 비건채식 비빔당면을 만들어 봤어요.
# 3인분 60분 이내 아무나
# 101 [비건채식] 두부전과 두부버거
# 비건채식하는 막둥이
# 반찬도시락 챙겨가 급식하고 있어요.
# 막둥이 급식메뉴가 햄버거라
# 두부전 만들어 두부버거 만들어
# 도시락에 담아 보냈어요.
# 6인분 이상 30분 이내 아무나
# 102 [비건채식]각한천으로 우묵을 만들었어요.
# 한천은 식이섬유 함유량이 다른 기존의 식품보다 월등히 높아 식이섬유소의 양이라고도 불립니다.
#
# 칼로리 부담은 적게, 포만감은 가득
#
# 다이어트 식품으로도 활용하고들 있죠.
#
# 우묵으로 만들어 봤어요.
#
# 수월하게 잘 만들어 지네요.
#
# 6인분 이상 90분 이내 아무나
# 103 [비건채식]호두흑설탕썰기떡을 만들었어요.
# 백년초가루, 단호박가루, 쑥가루로 만든 꽃과 잎이 너무 예쁘죠.
# 만드는 재미가 솔솔하네요.
# 6인분 이상 60분 이내 아무나
# 104 [비건채식]가장 간단한 무나물 만들었어요.
# 수확한 가을무
# 겨울동안 저장하여 간단하게
# 오신채를 사용하지 않고 무나물 만들었어요.
# 6인분 이상 15분 이내 아무나
# 105 [비건채식]밥할때 찐 된장국을 만들었어요.
# 간편하게 밥을 하면서 된장국까지 만드는 법이에요.
# 쌀위에 된장국그릇을 올려 밥을 하면
# 밥과 된장국이 만들어집니다.
# 3인분 60분 이내 아무나
# 106 [비건채식]채썬 고구마로 만든 고구마전
# 고구마로 튀김은 해 보았으나
# 고구마로 채 썰어 고구마전을 만들기는
# 처음 시도해 보았네요.
# 고소하고 맛있네요.
# 3인분 15분 이내 아무나
# 107 [비건채식] 간단한 재료로 잔파전 구웠어요.
# 비건채식 잔파전 구웠어요.
#
# 채식하고
# 오신채 없이 요리했었는데
#
# 오늘 잔파 구입해
#
# 처음으로 파전 굽고
# 처음으로 파전 먹었네요.
#
#
# 너무 맛있어
# 3판을 막둥이, 신랑과 같이
# 굽자마자 다 먹었네요.
#
# 3인분 15분 이내 아무나
# 108 [비건채식] 간단하게 치자로 물들인 단무지 만들기
# 간단하게
# 인공색소, 방부제 없이 단무지 만들었어요.
# 시중에 파는 단무지에 엄청은 많은 첨가물이 있어
# 김밥 만들때 노란색은 노란파프리카로 대신 했었는데요.
# 치자나무에 치자가 익어가고 있어
# 무, 치자, 천일염, 유기농황설탕, 물로 단무지 만들었어요.
# 가족들이 맛있게 먹네요.
# 6인분 이상 2시간 이상 아무나
# 109 [비건채식] 두부야채볶음 만들었어요.
# 아침에
# 냉장고에 있는 재료를 이용해
# 초스피드로 #비건채식두부야채볶음 을 만들었네요.
# 6인분 이상 30분 이내 아무나
# 110 [비건채식] 밀불구이뚝배기~~~
# 비건채식 밀불구이뚝배기~~~
# 걸쭉하고 진하고
# 시원하고 얼큰하네요.
#
#
# 비건채식 밀불구이뚝배기~
# 걸쭉하고 진하고시원하고 얼큰하네요.|
# 6인분 이상 30분 이내 아무나
# 111 [비건채식] 고기없이 두부로 두부두루치기 만들어 맛있게 먹었어요.
# 고기가 들어 가지 않은 두루치기---
# 고기 대신에 두부를 튀겨 이용했네요.
# 두부두루치기 맛있네요.
# 6인분 이상 60분 이내 아무나
# 112 [비건채식] 잡채
# 아침에
# 냉장고에 있는 재료로
# 비건채식 잡채 만들었어요.
#
# 6인분 이상 30분 이내 아무나
# 113 [비건채식]비건맛살 초밥 만들어요.
# 초밥 만들어
# 겨자 살짝 바르고
# 비건맛살 얹어
# 비건채식 초밥 만들었어요.
# 3인분 30분 이내 아무나
# 114 [비건채식] 시래기밥 만들었어요
# 쌀에 시래기, 표고버섯, 목이버섯을 넣고 시래기밥을 해 양념장에 비볐네요.
# 6인분 이상 2시간 이상 아무나
# 115 한그릇요리 버섯카레, 채식카레
# 고기대신 버섯을 듬뿍넣어 만든 버섯카레입니다. 고기의 고소함대신 담백함과 버섯의 쫄깃한 식감이 잘 어울리는 카레인데요.
# 새송이버섯, 송이버섯 등 개인의 취향에 맞추어 넣은 버섯종류에 따라 다른 맛을 느낄 수 있답니다.
# 6인분 이상 60분 이내 아무나
# 116 야채 된장찌개 만들기 채식 다시마육수 된장찌개 채수로 만든 두부된장찌개
# 야채 된장찌개 만들기 채식 다시마육수 된장찌개 채수로 만든 두부된장찌개
# 2인분 15분 이내 초급
# 117 맛있는 채식, 비건 스무디 [바나나두유스무디]
# 두유와 바나나를 갈아서 몸에 좋은 비건 스무디를 만들었습니다. 간단하면서도 든든해서 가벼운 식사대용으로 혹은 건강음료로 아주 좋은 스무디입니다.
# 1인분 5분 이내 아무나
# 118 청양고추와 병아리콩을 이용한 매콤채식카레
# 고구마와 병아리콩이 들어 있어 달콤하면서도 칼칼한 카레, 기름을 최소하하여 만든 채식 카레이기 때문에 아주 담백하고요~ 청양고추가 들어가 어른 입맛에도 딱 좋아요!
# 2인분 30분 이내 초급
# 119 비건채식 피자( 갓 빻은 우리집밀가루로 구운 비건채식 피자 )
# 120 비건채식 콩고기를 만들었어요.
# 121 비건채식 바나나커피아이스크림 쉽게 만들기
# 122 비건채식 감자자장면
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.view2_summary.st3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 123
# 124 우리집 빵으로 자리매김한 비건채식 베이글 만들었어요.
# 125 손이 가요 자꾸자꾸 ~ 비건채식 모닝빵
# 126 간단한 비건채식 쫄면
# 127 비건채식 4종류 발효빵
# 128 비건채식 코코아팥아이스바 만들기
# 129 비건채식 거대한 맘모스빵
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.ready_ingre3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 130
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.ready_ingre3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 131
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.ready_ingre3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 132
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.ready_ingre3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 133
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.ready_ingre3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 134
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.ready_ingre3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 135
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.ready_ingre3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 136
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.ready_ingre3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 137
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.ready_ingre3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 138
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.ready_ingre3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 139
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.ready_ingre3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 140
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.ready_ingre3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 141
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.ready_ingre3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 142
# 143 [비건채식]단호박조림
# 144 [비건 완전채식] 참외김치
# 145 [비건(완전채식)] 코코아 파운드 케잌
# 146 [비건채식] 견과류 호떡
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.ready_ingre3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 147
# 148 [비건(완전채식)] 바나나피칸컵케잌
# 149 [비건채식] 찹쌀도넛
# 150 [비건(완전채식)] 녹차아이스크림
# 151 [비건(완전채식)] 바나나팥아이스바
# 152 [비건(완전채식)] 미국식 코코아 와플
# 153 [비건(완전채식)] 블루베리 코코아컵케잌
# 154 버섯과 배추가 듬뿍 들어간 채식감자탕
# 고기 대신 버섯넣어 만든 채식 감자탕
# 초급
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.ready_ingre3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 155
# 156 채식주의자의 디저트 모카푸딩 만들기
# 커피향 그윽한 모카 푸딩으로 입맛도 깊어가는 가을을 느껴보세요. 가을과 참 잘 어울리는 후식인 것 같습니다.
# 5인분 30분 이내 중급
# 157 +다이어트 곤약카레라이스+ 채식으로 가벼운 식사해요 ^^
# 다이어트에도 좋은 곤약 카레라이스입니다!
# 2인분 30분 이내 아무나
# 158 채식인을 위한 두유초코칩쿠키
# 버터와 계란이 들어가지 않아 일반 쿠키보다 훨씬 더 담백하고 고소한 두유초코칩쿠키입니다.
# 6인분 이상 60분 이내 초급
# 159 믹서기로 휘리릭 채식 단호박머핀
# 초간단 달달한 단호박 머핀입니다.
# 3인분 30분 이내 초급
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.ready_ingre3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 160
# Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.ready_ingre3"}
#   (Session info: chrome=92.0.4515.131)
#  This page is error : 161
#
# 수집한 글 갯수:  140
#                                                  title  \
# 1    오늘 저녁은 채식위주로??? 에어프라이어표 버섯채소구이 ★\n냉장고에 있는 칭구들~...
# 2    녹차파운드케이크 : 노버터,통밀가루 나름 채식베이킹\n통밀가루를 이용해 제가 좋아하...
# 3    매콤 달콤한 팽이버섯 양념구이.(버섯요리, 밥반찬, 채식.)\n묶음으로 팔아서 팽이...
# 4    다이어트 채식주의자를 위한 치커리 샐러드/겉절이\n더워진 날씨 짧아진 옷차림~ 다이...
# 5    한그릇요리, 채식버섯리조또, 두유버섯리조또만들기\n우유나 생크림, 버터 대신 두유를...
# ..                                                 ...
# 154     버섯과 배추가 듬뿍 들어간 채식감자탕\n고기 대신 버섯넣어 만든 채식 감자탕\n초급
# 156  채식주의자의 디저트 모카푸딩 만들기\n커피향 그윽한 모카 푸딩으로 입맛도 깊어가는 ...
# 157  +다이어트 곤약카레라이스+ 채식으로 가벼운 식사해요 ^^\n다이어트에도 좋은 곤약 ...
# 158  채식인을 위한 두유초코칩쿠키\n버터와 계란이 들어가지 않아 일반 쿠키보다 훨씬 더 ...
# 159  믹서기로 휘리릭 채식 단호박머핀\n초간단 달달한 단호박 머핀입니다.\n3인분 30분...
#
#                                             ingredient  \
# 1    [필수재료]\n새송이버섯\n1개\n양송이버섯\n3개\n빨강파프리카\n1/2개\n노랑...
# 2    [재료]\n통밀가루\n160g\n두유\n160ml\n카놀라유\n60g\n설탕\n10...
# 3    [재료]\n팽이버섯\n450g\n통깨\n1/2큰술\n참기름\n1작은술\n[양념]\n...
# 4    [재료]\n치커리\n1웅큼\n파프리카\n1/2개\n적양파\n1/2개\n참깨\n적당량...
# 5    [재료]\n찬밥\n2공기\n새송이버섯\n2개\n파프리카\n1/2개\n양파\n1/2개...
# ..                                                 ...
# 154  [재료]\n감자(소)\n7개\n데친배추\n300g\n표고버섯\n4개\n애느타리버섯\...
# 156  [재료]\n포도씨유\n1큰술\n통밀가루\n2큰술\n한천가루\n1작은술\n두유\n2컵...
# 157  [재료]\n곤약\n100g\n감자\n50g\n양파\n70g\n호박\n80g\n브로컬...
# 158  [재료]\n카놀라유\n50g\n두유\n50g\n흑설탕\n40g\n설탕\n40g\n박...
# 159  [재료]\n단호박\n1/4개\n식물성오일\n35g\n우유\n84g(혹은 두유 동량)...
#
#                                                    pic  \
# 1    https://recipe1.ezmember.co.kr/cache/recipe/20...
# 2    https://recipe1.ezmember.co.kr/cache/recipe/20...
# 3    https://recipe1.ezmember.co.kr/cache/recipe/20...
# 4    https://recipe1.ezmember.co.kr/cache/recipe/20...
# 5    https://recipe1.ezmember.co.kr/cache/recipe/20...
# ..                                                 ...
# 154  https://recipe1.ezmember.co.kr/cache/recipe/20...
# 156  https://recipe1.ezmember.co.kr/cache/recipe/20...
# 157  https://recipe1.ezmember.co.kr/cache/recipe/20...
# 158  https://recipe1.ezmember.co.kr/cache/recipe/20...
# 159  https://recipe1.ezmember.co.kr/cache/recipe/20...
#
#                                                content
# 1    조리순서Steps\n버섯과 채소는 모두 한입 크기로 썬다.\n볼에 버섯, 채소를 담...
# 2    조리순서Steps\n원본보기\n재료를 준비합니다.\n계란 3개를 볼에 깨뜨려 넣은 ...
# 3    조리순서Steps\n양념을 비율대로 골고루 섞어둔다.\n밑둥을 자르고 결대로 찢은 ...
# 4    조리순서Steps\n치커리 한웅큼을 흐르는 물에 깨끗이 씻은 후 먹기 좋은 크기로 ...
# 5    조리순서Steps\n양파와 파프리카, 버섯은 먹기좋은 크기로 다져줍니다.\n새송이버...
# ..                                                 ...
# 154  조리순서Steps\n원본보기\n대파, 양파 넣고 육수 만들어 주세요\n물7컵에 채수...
# 156  조리순서Steps\n원본보기\n냄비에 포도씨유와 통밀가루를 넣고 약한 불에서 고루 ...
# 157  조리순서Steps\n원본보기\n모든 재료는 깍둑썰기해서 준비해주세요.\n기름을 아주...
# 158  조리순서Steps\n원본보기\n카놀라유, 두유, 흑설탕, 설탕을 골고루 섞어 주세요...
# 159  조리순서Steps\n원본보기\n분량의 단호박의 1/2는 작게 잘라준후 렌지에 넣고 ...
#
# [140 rows x 4 columns]

# %%
result_df.to_csv("10000_recipe_채식.csv", encoding='utf-8') #csv파일로 저장
